# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib import animation
from utils import *

animation.writer = animation.writers['ffmpeg']

# %%
altitude = 50. # m
x_pos = 5. # m? (don't think this really matters)
entrance_x_vel = 10. # m/s
pos = (x_pos, altitude)
gamma = 0

results = {}
rho_vals = [1, .1, .01, .001, .00000000001]
for rho in rho_vals:
    results[rho]  = lunar_lander_final_angle(pos, entrance_x_vel, gamma=0, beta=100, nu=5000, t_steps=10000, rho=rho, final_angle_on=True)

# TODO: Try out just doing the angle without the nu stuff

# %%
for rho in rho_vals:
    print("Rho = ", rho)
    TS, X, Y, XP, YP, UX, UY, TF = results[rho]
    make_trajectory_plot(X, Y)
    make_plots(TS, X, Y, XP, YP, UX, UY, TF)
# Out:
# Rho =  1
# Final Time: 10.68837411277318
# Final Position: (50.169, -0.0)
# Rho =  0.1
# Final Time: 1.336005702248851
# Final Position: (-6.813, -0.0)
# Rho =  0.01
# Final Time: 8.630572759361248
# Final Position: (39.853, 0.0)
# Rho =  0.001
# Final Time: 4.408875756371614
# Final Position: (5.048, 0.0)
# Rho =  1e-11
# Final Time: 2389.992978258232
# Final Position: (-7425008.823, -1077373.0)

# %%
# Out:
# Final Time: 10.634942585380553
# Final Position: (49.908, 0.0)
