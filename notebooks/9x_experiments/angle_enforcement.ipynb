# %%
import numpy as np
from scipy.integrate import solve_bvp
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib import animation
from utils import *
from itertools import product

animation.writer = animation.writers['ffmpeg']

# %%
altitude = 50. # m
x_pos = 5. # m? (don't think this really matters)
entrance_x_vel = 10. # m/s
pos = (x_pos, altitude)
gamma = 0


zeta_vals = [.1, 1, 10, 100]
results = {zeta:{} for zeta in zeta_vals}

eps_vals = [0.1, 1, 5]
for zeta, eps in product(zeta_vals, eps_vals):
    results[zeta][eps]  = lunar_lander_final_angle_v2(pos, entrance_x_vel, gamma=0, beta=100, nu=5000, t_steps=10000, zeta=zeta, eps=eps, final_angle_on=True)

# TODO: Try out just doing the angle without the nu stuff

# %%
for zeta, eps in product(zeta_vals, eps_vals):
    print("Zeta = ", zeta, "Eps = ", eps)
    TS, X, Y, XP, YP, UX, UY, TF = results[zeta][eps]
    make_trajectory_plot(X, Y)
    make_plots(TS, X, Y, XP, YP, UX, UY, TF)
# Out:
# Zeta =  0.1 Eps =  0.1
# Final Time: 10.631059400870775
# Final Position: (49.896, 0.0)
# Zeta =  0.1 Eps =  1
# Final Time: 10.63316445110808
# Final Position: (49.891, 0.0)
# Zeta =  0.1 Eps =  5
# Final Time: 10.607980201323862
# Final Position: (49.761, 0.0)
# Zeta =  1 Eps =  0.1
# Final Time: 10.632723176539736
# Final Position: (49.895, 0.0)
# Zeta =  1 Eps =  1
# Final Time: 10.597034597330776
# Final Position: (49.699, -0.0)
# Zeta =  1 Eps =  5
# Final Time: 11.613312504490397
# Final Position: (62.581, -0.0)
# Zeta =  10 Eps =  0.1
# Final Time: 10.610166771521715
# Final Position: (49.763, -0.0)
# Zeta =  10 Eps =  1
# Final Time: 13.69224197221235
# Final Position: (74.043, 0.0)
# Zeta =  10 Eps =  5
# Final Time: -7.886219978250317
# Final Position: (-10.854, -0.0)
# Zeta =  100 Eps =  0.1
# Final Time: 13.02498687393241
# Final Position: (69.81, -0.0)
# Zeta =  100 Eps =  1
# Final Time: -2.1728838959127783
# Final Position: (-2.19, -0.0)
# Zeta =  100 Eps =  5
# ...
